# %% [markdown]
# This notebook explores and cleans 'final_book_dataset.csv'.
# I specifically:
# - Removed the column index column
# - Turned all entries in title_id into integers
# - Turned all author birthyears into integers
# - Turned all isbns into strings, so hopefully we get less warnings about this column's dtypes
# - I also parsed the raw HTML book_synopsis entries using html2text. Hopefully this results in something better to use

# %%
import numpy as np
import pandas as pd

# %%
books = pd.read_csv('final_book_dataset.csv', sep='\t')
books = books[['title_id', 'title', 'author', 'release_year',
       'release_date', 'first_publisher', 'author_birthyear',
       'author_birthplace', 'isbn', 'book_synopsis', 'tags', 'hugo', 'locus']]
# Out:
# /tmp/ipykernel_28341/3878242122.py:1: DtypeWarning: Columns (0: isbn) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv('final_book_dataset.csv', sep='\t')

# %%
books.title_id = books.title_id.astype('Int64')
books.author_birthyear = books.author_birthyear.astype('Int64')
books.isbn = books.isbn.astype('str')
books.sample(5)
# Out:
#         title_id              title                        author  \
# 37895    1318938     The Chosen One              Kenneth E. Baker
# 75127    2141910     Siege of Night                   Jeff Gunzel
# 83835    1808357         Homecoming                   Kass Morgan
# 117274   2611583  Shields in Shadow                 Andy Peloquin
# 103678   3211308     Dead Reckoning  Jack Colrain, Grace Hamilton
#
#         release_year release_date      first_publisher  author_birthyear  \
# 37895           2004   2004-00-00  Whiskey Creek Press              <NA>
# 75127           2014   2014-01-19          Jeff Gunzel              <NA>
# 83835           2015   2015-02-24        Little, Brown              1984
# 117274          2019   2019-08-19        Andy Peloquin              <NA>
# 103678          2018   2018-06-14     Relay Publishing              <NA>
#
#                    author_birthplace             isbn  \
# 37895                            NaN       1593741014
# 75127                            NaN              NaN
# 83835   New York City, New York, USA  9780316381963.0
# 117274                         Japan  9781686195921.0
# 103678                           NaN  9781721136407.0
#
#                                             book_synopsis  \
# 37895                                                 NaN
# 75127                                                 NaN
# 83835   Humanity is coming home. Weeks after landing o...
# 117274                                                NaN
# 103678                                                NaN
#
#                                                      tags   hugo  locus
# 37895                                 ['Science fiction']  False  False
# 75127                                         ['fantasy']  False  False
# 83835   ['young-adult sf', 'Juvenile Fiction', 'Young ...  False  False
# 117274                               ['military fantasy']  False  False
# 103678                                                NaN  False  False

# %%
# Use html2text to parse the descriptions
# Install only once of course
#%pip install -U html2text

# %%
import html2text

def exception_handled_htmlparse(x):
    try:
        return html2text.html2text(x)
    except AttributeError:
        if pd.isnull(x):
            return ''
        print(x)
    return x

# %%
books.book_synopsis = books.book_synopsis.apply(exception_handled_htmlparse)

# %%
books
# Out:
#         title_id                               title  \
# 0           9372               The Long Loud Silence
# 1        2215181          Mrs. Candy Strikes It Rich
# 2        1392436           Return to the Lost Planet
# 3        1112206                 Rainbow on the Road
# 4           1908                The Forgotten Planet
# ...          ...                                 ...
# 151586   3506914          Daughter of the Underworld
# 151587   3506911  We Are Always Tender with Our Dead
# 151588   3506908      They Fear Not Men in the Woods
# 151589   3506905                Press 1 for Invasion
# 151590      <NA>                 The Tomb of Dragons
#
#                                 author  release_year release_date  \
# 0                        Wilson Tucker          1954   1954-00-00
# 1                       Robert Tallant          1954   1954-00-00
# 2                       Angus MacVicar          1954   1954-00-00
# 3                        Esther Forbes          1954   1954-00-00
# 4                      Murray Leinster          1954   1954-00-00
# ...                                ...           ...          ...
# 151586  Katharine Corr, Elizabeth Corr          2025   2025-09-09
# 151587                    Eric LaRocca          2025   2025-09-09
# 151588                 Gretchen McNeil          2025   2025-09-09
# 151589                    J. A. Dauber          2025   2025-09-09
# 151590               Katherine Addison          2025          NaN
#
#          first_publisher  author_birthyear                author_birthplace  \
# 0                   Dell              1914        Deer Creek, Illinois, USA
# 1              Doubleday              1909      New Orleans, Louisiana, USA
# 2                  Burke              1908      Duror, Argyll, Scotland, UK
# 3       Houghton Mifflin              1891  Westborough, Massachusetts, USA
# 4              Ace Books              1896           Norfolk, Virginia, USA
# ...                  ...               ...                              ...
# 151586  Candlewick Press              <NA>                              NaN
# 151587       Titan Books              <NA>                 Connecticut, USA
# 151588         DAW Books              1983   San Francisco, California, USA
# 151589           Aladdin              <NA>                              NaN
# 151590         Tor Books              <NA>                              NaN
#
#                    isbn                                      book_synopsis  \
# 0            0899683754  Publisher's description: Tomorrow's war -- the...
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4            0881846163  **From the first page of the Ace Double:** "Na...
# ...                 ...                                                ...
# 151586  9781536244533.0  Join a thrilling journey into the Underworld, ...
# 151587  9781803368672.0  A chilling supernatural tale of transgressive ...
# 151588  9780756420086.0  When Jen Monroe hears her father's remains hav...
# 151589  9781665974776.0
# 151590  9781250821027.0  Thara Celehar has lost his ability to speak wi...
#
#                                                      tags   hugo  locus
# 0       ['Anatomy of Wonder 1 Core Collection', 'biolo...  False  False
# 1                                                     NaN  False  False
# 2                                                     NaN  False  False
# 3                                                     NaN  False  False
# 4       ['insects', 'Librivox', 'Project Gutenberg', '...  False  False
# ...                                                   ...    ...    ...
# 151586  ['Young Adult Fiction', 'Fantasy', 'Young Adul...  False  False
# 151587  ['Fiction', 'LGBTQ', 'Fantasy', 'TBB The Grave...  False  False
# 151588                                        ['Fiction']  False  False
# 151589                                    ['juvenile sf']  False  False
# 151590  ['Fantasy', 'Fiction', 'Science Fiction', 'LGB...  False   True
#
# [151591 rows x 13 columns]

# %%
books.to_csv('final_book_dataset_cleaned.csv', sep='\t', index=False)

# %%
test = pd.read_csv('final_book_dataset_cleaned.csv', dtype={'isbn' : 'str'}, sep='\t')

# %%
test
# Out:
#          title_id                               title  \
# 0          9372.0               The Long Loud Silence
# 1       2215181.0          Mrs. Candy Strikes It Rich
# 2       1392436.0           Return to the Lost Planet
# 3       1112206.0                 Rainbow on the Road
# 4          1908.0                The Forgotten Planet
# ...           ...                                 ...
# 151586  3506914.0          Daughter of the Underworld
# 151587  3506911.0  We Are Always Tender with Our Dead
# 151588  3506908.0      They Fear Not Men in the Woods
# 151589  3506905.0                Press 1 for Invasion
# 151590        NaN                 The Tomb of Dragons
#
#                                 author  release_year release_date  \
# 0                        Wilson Tucker          1954   1954-00-00
# 1                       Robert Tallant          1954   1954-00-00
# 2                       Angus MacVicar          1954   1954-00-00
# 3                        Esther Forbes          1954   1954-00-00
# 4                      Murray Leinster          1954   1954-00-00
# ...                                ...           ...          ...
# 151586  Katharine Corr, Elizabeth Corr          2025   2025-09-09
# 151587                    Eric LaRocca          2025   2025-09-09
# 151588                 Gretchen McNeil          2025   2025-09-09
# 151589                    J. A. Dauber          2025   2025-09-09
# 151590               Katherine Addison          2025          NaN
#
#          first_publisher  author_birthyear                author_birthplace  \
# 0                   Dell            1914.0        Deer Creek, Illinois, USA
# 1              Doubleday            1909.0      New Orleans, Louisiana, USA
# 2                  Burke            1908.0      Duror, Argyll, Scotland, UK
# 3       Houghton Mifflin            1891.0  Westborough, Massachusetts, USA
# 4              Ace Books            1896.0           Norfolk, Virginia, USA
# ...                  ...               ...                              ...
# 151586  Candlewick Press               NaN                              NaN
# 151587       Titan Books               NaN                 Connecticut, USA
# 151588         DAW Books            1983.0   San Francisco, California, USA
# 151589           Aladdin               NaN                              NaN
# 151590         Tor Books               NaN                              NaN
#
#                    isbn                                      book_synopsis  \
# 0            0899683754  Publisher's description: Tomorrow's war -- the...
# 1                   NaN                                                NaN
# 2                   NaN                                                NaN
# 3                   NaN                                                NaN
# 4            0881846163  **From the first page of the Ace Double:** "Na...
# ...                 ...                                                ...
# 151586  9781536244533.0  Join a thrilling journey into the Underworld, ...
# 151587  9781803368672.0  A chilling supernatural tale of transgressive ...
# 151588  9780756420086.0  When Jen Monroe hears her father's remains hav...
# 151589  9781665974776.0                                                NaN
# 151590  9781250821027.0  Thara Celehar has lost his ability to speak wi...
#
#                                                      tags   hugo  locus
# 0       ['Anatomy of Wonder 1 Core Collection', 'biolo...  False  False
# 1                                                     NaN  False  False
# 2                                                     NaN  False  False
# 3                                                     NaN  False  False
# 4       ['insects', 'Librivox', 'Project Gutenberg', '...  False  False
# ...                                                   ...    ...    ...
# 151586  ['Young Adult Fiction', 'Fantasy', 'Young Adul...  False  False
# 151587  ['Fiction', 'LGBTQ', 'Fantasy', 'TBB The Grave...  False  False
# 151588                                        ['Fiction']  False  False
# 151589                                    ['juvenile sf']  False  False
# 151590  ['Fantasy', 'Fiction', 'Science Fiction', 'LGB...  False   True
#
# [151591 rows x 13 columns]
